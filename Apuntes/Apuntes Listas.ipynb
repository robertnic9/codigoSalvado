# %%
cadena= "hola que tal pascual"
cadena.replace("hola", "helo")
print(cadena)
# Out:
# hola que tal pascual

# %%
print(cadena.upper())
print(cadena)
# Out:
# HOLA QUE TAL PASCUAL
# hola que tal pascual

# %%
#metodos de lsitas 
#añadir elementos
lista_2=[2,3,"janders"]
lista_3 = [23,4,1.5,25.5, "hola", True, False]
lista_3.pop()
#añadir cosas = .append
lista_3.append([1,3])

#lista4 = lista 2 + lista 3 o el comando .extend creando una lista vacia : lista_4=list()
lista_4 = lista_2 + lista_3
# cuando se hace una suma se fusiona 
#y cuando se hace un append se convierte en un elemento mas 
lista_3.append(lista_2)
print(f"append = {lista_3}")
print(f"suma = {lista_4}")
# Out:
# append = [23, 4, 1.5, 25.5, 'hola', True, [1, 3], [2, 3, 'janders']]
# suma = [2, 3, 'janders', 23, 4, 1.5, 25.5, 'hola', True, [1, 3]]

# %%
#contar el numero de elementos = función len(lista)
print("El número de elementos de lista_3 es: ", len(lista_3))
print("El número de elementos de lsita_4 es : ", len(lista_4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #contar el numero de elementos = función len(lista)
# ----> 2 print("El número de elementos de lista_3 es: ", len(lista_3))
#       3 print("El número de elementos de lsita_4 es : ", len(lista_4))
#
# NameError: name 'lista_3' is not defined

# %%
lista= [1,2,3,4,5,5,6,7,8,8]
#insertar elementos dentro de la lista en una posición determinada
#método lista.insert(i,x)
lista.insert(1,9)
print(lista)
#Eliminar elementos de la lista = lista.remove(x)
lista.remove(8)
print (lista)
lista= lista + [1,1,2,2,3,3]
print(lista)
# Out:
# [1, 9, 2, 3, 4, 5, 5, 6, 7, 8, 8]
# [1, 9, 2, 3, 4, 5, 5, 6, 7, 8]
# [1, 9, 2, 3, 4, 5, 5, 6, 7, 8, 1, 1, 2, 2, 3, 3]

# %%
#contador de repetidos = lista.count(x) = cuenta las veces que aparece 
# el elemento x en la lista y devuelve un entero 
print(lista.count(1))
# Out:
# 3

# %%
lista.extend(["hola","hola", [1,2,3],"janders"])
print(lista)
# Out:
# [1, 9, 2, 3, 4, 5, 5, 6, 7, 8, 1, 1, 2, 2, 3, 3, 'hola', 'hola', [1, 2, 3], 'janders']

# %%
#ordenar elementos de la lista de menor a mayor = lista.sort()
lista=[1,2,7,4,9,3,7,4,8]
lista.sort()
print(lista)
# te puede ordenar en orden alfabetico si son de la misma forma
#en plan palabras con palabras
#lista.sort(reverse=True) para que sea al inrevers
# Out:
# [1, 2, 3, 4, 4, 7, 7, 8, 9]

# %%
#metodo de lsita para conocer la posición de un elemento dentro de ella 
#list.index()
list.index()
lista = [1,2,4,2,5,7,2,5]

# %%
#metodo para borrar en contenido de la lista lista.remove
print(lista)

# %%
#metodo para max(list)
#metodo min(list)

# %%
#Para borrar un elemento o un objeto completo tenemos la función del ()
lista=["hola",1,2,3,4,"jander"]
del(lista[5])
print(lista)
#elimina el ultimo elemento y me lo devuelve con la funvion .pop 
elem =lista.pop()
print("El elemento elimando con la función pop(): ", elem)
# Out:
# ['hola', 1, 2, 3, 4]
# El elemento elimando con la función pop():  4

# %%
#para hacer que la lista selecione a cada salto es 
lista=[2,34,5,3,5,3,6,8,4]
sublista= lista[0::2]
print(sublista)
# Out:
# [2, 5, 5, 6, 4]

# %%
lista=[2,34,5,3,5,3,6,8,4]
invertida = lista[::-1]
print(invertida)
# Out:
# [4, 8, 6, 3, 5, 3, 5, 34, 2]
